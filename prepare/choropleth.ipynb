# %%
import pandas as pd;
import numpy as np;
import re;

profile_df = pd.read_csv('../static/data/original/neighbourhood-profiles-2016-csv.csv')
profile_df.head()
# Out:
#    _id                   Category                      Topic  \
# 0    1  Neighbourhood Information  Neighbourhood Information
# 1    2  Neighbourhood Information  Neighbourhood Information
# 2    3                 Population   Population and dwellings
# 3    4                 Population   Population and dwellings
# 4    5                 Population   Population and dwellings
#
#                       Data Source               Characteristic  \
# 0                 City of Toronto         Neighbourhood Number
# 1                 City of Toronto         TSNS2020 Designation
# 2  Census Profile 98-316-X2016001             Population, 2016
# 3  Census Profile 98-316-X2016001             Population, 2011
# 4  Census Profile 98-316-X2016001  Population Change 2011-2016
#
#   City of Toronto Agincourt North Agincourt South-Malvern West  \
# 0             NaN             129                          128
# 1             NaN  No Designation               No Designation
# 2       2,731,571          29,113                       23,757
# 3       2,615,060          30,279                       21,988
# 4           4.50%          -3.90%                        8.00%
#
#         Alderwood           Annex  ... Willowdale West  \
# 0              20              95  ...              37
# 1  No Designation  No Designation  ...  No Designation
# 2          12,054          30,526  ...          16,936
# 3          11,904          29,177  ...          15,004
# 4           1.30%           4.60%  ...          12.90%
#
#   Willowridge-Martingrove-Richview  Woburn Woodbine Corridor Woodbine-Lumsden  \
# 0                                7     137                64               60
# 1                   No Designation     NIA    No Designation   No Designation
# 2                           22,156  53,485            12,541            7,865
# 3                           21,343  53,350            11,703            7,826
# 4                            3.80%   0.30%             7.20%            0.50%
#
#          Wychwood  Yonge-Eglinton  Yonge-St.Clair York University Heights  \
# 0              94             100              97                      27
# 1  No Designation  No Designation  No Designation                     NIA
# 2          14,349          11,817          12,528                  27,593
# 3          13,986          10,578          11,652                  27,713
# 4           2.60%          11.70%           7.50%                  -0.40%
#
#        Yorkdale-Glen Park
# 0                      31
# 1  Emerging Neighbourhood
# 2                  14,804
# 3                  14,687
# 4                   0.80%
#
# [5 rows x 146 columns]

# %%
crime_df = pd.read_csv('../static/data/original/neighbourhood-crime-rates.csv')
crime_df.head()
# Out:
#    _id  OBJECTID            Neighbourhood  Hood_ID  \
# 0    1         1           Yonge-St.Clair       97
# 1    2         2  York University Heights       27
# 2    3         3         Lansing-Westgate       38
# 3    4         4       Yorkdale-Glen Park       31
# 4    5         5      Stonegate-Queensway       16
#
#    F2020_Population_Projection  Assault_2014  Assault_2015  Assault_2016  \
# 0                        14083            16            25            34
# 1                        30277           273           298           363
# 2                        18146            42            81            67
# 3                        17560           106           137           175
# 4                        27410            91            74            78
#
#    Assault_2017  Assault_2018  ...  Shootings_2019  Shootings_2020  \
# 0            25            28  ...               0               0
# 1           351           362  ...               6              12
# 2            84            68  ...               2               1
# 3           163           178  ...              17              14
# 4            98            86  ...               1               0
#
#    Shooting_Rate2014  Shootings_Rate2015  Shootings_Rate2016  \
# 0           0.000000            0.000000            7.722008
# 1           6.963789            0.000000           13.986990
# 2           0.000000            0.000000            5.980146
# 3          19.740740           19.752440           19.700550
# 4          11.702290            7.788465            0.000000
#
#    Shootings_Rate2017  Shootings_Rate2018  Shootings_Rate2019  \
# 0            0.000000            0.000000            0.000000
# 1           34.504170           27.189610           20.102520
# 2            0.000000            5.737564           11.245430
# 3           44.312210           61.042610          100.170900
# 4            3.821754            3.759257            3.702744
#
#    Shootings_Rate2020                                           geometry
# 0            0.000000  {u'type': u'Polygon', u'coordinates': (((-79.3...
# 1           39.634040  {u'type': u'Polygon', u'coordinates': (((-79.5...
# 2            5.510856  {u'type': u'Polygon', u'coordinates': (((-79.4...
# 3           79.726650  {u'type': u'Polygon', u'coordinates': (((-79.4...
# 4            0.000000  {u'type': u'Polygon', u'coordinates': (((-79.4...
#
# [5 rows x 104 columns]

# %% [markdown]
# ## Fix neighbourhood names

# %%
# get the intersection of two data above
# Get neighbourhood names from profile_df (excluding non-neighbourhood columns)
profile_neighbourhoods = set(profile_df.columns[6:])  # Skip first 6 columns which are metadata

# Get neighbourhood names from crime_df
crime_neighbourhoods = set(crime_df["Neighbourhood"])

# Get the intersection
common_neighbourhoods = profile_neighbourhoods.intersection(crime_neighbourhoods)

# Print results
print(f"Profile neighbourhoods: {len(profile_neighbourhoods)}")
print(f"Crime neighbourhoods: {len(crime_neighbourhoods)}")
print(f"Common neighbourhoods: {len(common_neighbourhoods)}")
print("\nMissing in crime data:", profile_neighbourhoods - crime_neighbourhoods)
print("\nMissing in profile data:", crime_neighbourhoods - profile_neighbourhoods)
# Out:
# Profile neighbourhoods: 140
# Crime neighbourhoods: 140
# Common neighbourhoods: 137
#
# Missing in crime data: {'Cabbagetown-South St. James Town', 'North St. James Town', 'Weston-Pelham Park'}
#
# Missing in profile data: {'North St.James Town', 'Weston-Pellam Park', 'Cabbagetown-South St.James Town'}

# %%
# Create a mapping dictionary for the inconsistent names
name_mapping = {
    'Cabbagetown-South St.James Town': 'Cabbagetown-South St. James Town',
    'North St.James Town': 'North St. James Town',
    'Weston-Pellam Park': 'Weston-Pelham Park'
}

# Replace the names in crime_df
crime_df['Neighbourhood'] = crime_df['Neighbourhood'].replace(name_mapping)

# Verify the intersection again
crime_neighbourhoods = set(crime_df["Neighbourhood"])
common_neighbourhoods = profile_neighbourhoods.intersection(crime_neighbourhoods)
print(f"Common neighbourhoods after fix: {len(common_neighbourhoods)}")
# Out:
# Common neighbourhoods after fix: 140

# %% [markdown]
# ## Clean Profile Data

# %%
# Count NaN values for each column
nan_counts = profile_df.isna().sum()

# Show only columns that have NaN values (if any)
columns_with_nans = nan_counts[nan_counts > 0]
print("Columns with NaN values:")
print(columns_with_nans)

# For columns with NaN values, show unique Category-Topic combinations
if len(columns_with_nans) > 0:
    for col in columns_with_nans.index:
        print(f"\nUnique Category-Topic combinations where {col} is NaN:")
        unique_combinations = profile_df[profile_df[col].isna()][['Category', 'Topic']].drop_duplicates()
        print(unique_combinations)
# Out:
# Columns with NaN values:
# City of Toronto                  7
# Agincourt North                 56
# Agincourt South-Malvern West    56
# Alderwood                       56
# Annex                           56
#                                 ..
# Wychwood                        56
# Yonge-Eglinton                  56
# Yonge-St.Clair                  56
# York University Heights         56
# Yorkdale-Glen Park              56
# Length: 141, dtype: int64
#
# Unique Category-Topic combinations where City of Toronto is NaN:
#                        Category                      Topic
# 0     Neighbourhood Information  Neighbourhood Information
# 1960            Journey to work      Commuting destination
#
# Unique Category-Topic combinations where Agincourt North is NaN:
#              Category                                    Topic
# 946            Income            Income of individuals in 2015
# 1014           Income             Income of households in 2015
# 1076           Income      Income of economic families in 2015
# 1681          Housing                        Core housing need
# 1912           Labour  Work activity during the reference year
# 1962  Journey to work                    Commuting destination
#
# Unique Category-Topic combinations where Agincourt South-Malvern West is NaN:
#              Category                                    Topic
# 946            Income            Income of individuals in 2015
# 1014           Income             Income of households in 2015
# 1076           Income      Income of economic families in 2015
# 1681          Housing                        Core housing need
# 1912           Labour  Work activity during the reference year
# 1962  Journey to work                    Commuting destination
#
# Unique Category-Topic combinations where Alderwood is NaN:
#              Category                                    Topic
# 946            Income            Income of individuals in 2015
# 1014           Income             Income of households in 2015
# 1076           Income      Income of economic families in 2015
# 1681          Housing                        Core housing need
# 1912           Labour  Work activity during the reference year
# 1962  Journey to work                    Commuting destination
#
# Unique Category-Topic combinations where Annex is NaN:
#              Category                                    Topic
# 946            Income            Income of individuals in 2015
# 1014           Income             Income of households in 2015
# 1076           Income      Income of economic families in 2015
# 1681          Housing                        Core housing need
# 1912           Labour  Work activity during the reference year
# 1962  Journey to work                    Commuting destination
#
# Unique Category-Topic combinations where Banbury-Don Mills is NaN:
#              Category                                    Topic
# 946            Income            Income of individuals in 2015
# 1014           Income             Income of households in 2015
# 1076           Income      Income of economic families in 2015
# 1681          Housing                        Core housing need
# 1912           Labour  Work activity during the reference year
# 1962  Journey to work                    Commuting destination
#
# Unique Category-Topic combinations where Bathurst Manor is NaN:
#              Category                                    Topic
# 946            Income            Income of individuals in 2015
# 1014           Income             Income of households in 2015
# 1076           Income      Income of economic families in 2015
# 1681          Housing                        Core housing need
# 1912           Labour  Work activity during the reference year
# 1962  Journey to work                    Commuting destination
#
# Unique Category-Topic combinations where Bay Street Corridor is NaN:
#              Category                                    Topic
# 946            Income            Income of individuals in 2015
# 1014           Income             Income of households in 2015
# 1076           Income      Income of economic families in 2015
# 1681          Housing                        Core housing need
# 1912           Labour  Work activity during the reference year
# 1962  Journey to work                    Commuting destination
#
# Unique Category-Topic combinations where Bayview Village is NaN:
#              Category                                    Topic
# 946            Income            Income of individuals in 2015
# 1014           Income             Income of households in 2015
# 1076           Income      Income of economic families in 2015
# 1681          Housing                        Core housing need
# 1912           Labour  Work activity during the reference year
# 1962  Journey to work                    Commuting destination
#
# Unique Category-Topic combinations where Bayview Woods-Steeles is NaN:
#              Category                                    Topic
# 946            Income            Income of individuals in 2015
# 1014           Income             Income of households in 2015
# 1076           Income      Income of economic families in 2015
# 1681          Housing                        Core housing need
# 1912           Labour  Work activity during the reference year
# 1962  Journey to work                    Commuting destination
#
# Unique Category-Topic combinations where Bedford Park-Nortown is NaN:
#              Category                                    Topic
# 946            Income            Income of individuals in 2015
# 1014           Income             Income of households in 2015
# 1076           Income      Income of economic families in 2015
# 1681          Housing                        Core housing need
# 1912           Labour  Work activity during the reference year
# 1962  Journey to work                    Commuting destination
#
# Unique Category-Topic combinations where Beechborough-Greenbrook is NaN:
#              Category                                    Topic
# 946            Income            Income of individuals in 2015
# 1014           Income             Income of households in 2015
# 1076           Income      Income of economic families in 2015
# 1681          Housing                        Core housing need
# 1912           Labour  Work activity during the reference year
# 1962  Journey to work                    Commuting destination
#
# Unique Category-Topic combinations where Bendale is NaN:
#              Category                                    Topic
# 946            Income            Income of individuals in 2015
# 1014           Income             Income of households in 2015
# 1076           Income      Income of economic families in 2015
# 1681          Housing                        Core housing need
# 1912           Labour  Work activity during the reference year
# 1962  Journey to work                    Commuting destination
#
# Unique Category-Topic combinations where Birchcliffe-Cliffside is NaN:
#              Category                                    Topic
# 946            Income            Income of individuals in 2015
# 1014           Income             Income of households in 2015
# 1076           Income      Income of economic families in 2015
# 1681          Housing                        Core housing need
# 1912           Labour  Work activity during the reference year
# 1962  Journey to work                    Commuting destination
#
# Unique Category-Topic combinations where Black Creek is NaN:
#              Category                                    Topic
# 946            Income            Income of individuals in 2015
# 1014           Income             Income of households in 2015
# 1076           Income      Income of economic families in 2015
# 1681          Housing                        Core housing need
# 1912           Labour  Work activity during the reference year
# 1962  Journey to work                    Commuting destination
#
# Unique Category-Topic combinations where Blake-Jones is NaN:
#              Category                                    Topic
# 946            Income            Income of individuals in 2015
# 1014           Income             Income of households in 2015
# 1076           Income      Income of economic families in 2015
# 1681          Housing                        Core housing need
# 1912           Labour  Work activity during the reference year
# 1962  Journey to work                    Commuting destination
#
# Unique Category-Topic combinations where Briar Hill-Belgravia is NaN:
#              Category                                    Topic
# 946            Income            Income of individuals in 2015
# 1014           Income             Income of households in 2015
# 1076           Income      Income of economic families in 2015
# 1681          Housing                        Core housing need
# 1912           Labour  Work activity during the reference year
# 1962  Journey to work                    Commuting destination
#
# Unique Category-Topic combinations where Bridle Path-Sunnybrook-York Mills is NaN:
#              Category                                    Topic
# 946            Income            Income of individuals in 2015
# 1014           Income             Income of households in 2015
# 1076           Income      Income of economic families in 2015
# 1681          Housing                        Core housing need
# 1912           Labour  Work activity during the reference year
# 1962  Journey to work                    Commuting destination
#
# Unique Category-Topic combinations where Broadview North is NaN:
#              Category                                    Topic
# 946            Income            Income of individuals in 2015
# 1014           Income             Income of households in 2015
# 1076           Income      Income of economic families in 2015
# 1681          Housing                        Core housing need
# 1912           Labour  Work activity during the reference year
# 1962  Journey to work                    Commuting destination
#
# Unique Category-Topic combinations where Brookhaven-Amesbury is NaN:
#              Category                                    Topic
# 946            Income            Income of individuals in 2015
# 1014           Income             Income of households in 2015
# 1076           Income      Income of economic families in 2015
# 1681          Housing                        Core housing need
# 1912           Labour  Work activity during the reference year
# 1962  Journey to work                    Commuting destination
#
# Unique Category-Topic combinations where Cabbagetown-South St. James Town is NaN:
#              Category                                    Topic
# 946            Income            Income of individuals in 2015
# 1014           Income             Income of households in 2015
# 1076           Income      Income of economic families in 2015
# 1681          Housing                        Core housing need
# 1912           Labour  Work activity during the reference year
# 1962  Journey to work                    Commuting destination
#
# Unique Category-Topic combinations where Caledonia-Fairbank is NaN:
#              Category                                    Topic
# 946            Income            Income of individuals in 2015
# 1014           Income             Income of households in 2015
# 1076           Income      Income of economic families in 2015
# 1681          Housing                        Core housing need
# 1912           Labour  Work activity during the reference year
# 1962  Journey to work                    Commuting destination
#
# Unique Category-Topic combinations where Casa Loma is NaN:
#              Category                                    Topic
# 946            Income            Income of individuals in 2015
# 1014           Income             Income of households in 2015
# 1076           Income      Income of economic families in 2015
# 1681          Housing                        Core housing need
# 1912           Labour  Work activity during the reference year
# 1962  Journey to work                    Commuting destination
#
# Unique Category-Topic combinations where Centennial Scarborough is NaN:
#              Category                                    Topic
# 946            Income            Income of individuals in 2015
# 1014           Income             Income of households in 2015
# 1076           Income      Income of economic families in 2015
# 1681          Housing                        Core housing need
# 1912           Labour  Work activity during the reference year
# 1962  Journey to work                    Commuting destination
#
# Unique Category-Topic combinations where Church-Yonge Corridor is NaN:
#              Category                                    Topic
# 946            Income            Income of individuals in 2015
# 1014           Income             Income of households in 2015
# 1076           Income      Income of economic families in 2015
# 1681          Housing                        Core housing need
# 1912           Labour  Work activity during the reference year
# 1962  Journey to work                    Commuting destination
#
# Unique Category-Topic combinations where Clairlea-Birchmount is NaN:
#              Category                                    Topic
# 946            Income            Income of individuals in 2015
# 1014           Income             Income of households in 2015
# 1076           Income      Income of economic families in 2015
# 1681          Housing                        Core housing need
# 1912           Labour  Work activity during the reference year
# 1962  Journey to work                    Commuting destination
#
# Unique Category-Topic combinations where Clanton Park is NaN:
#              Category                                    Topic
# 946            Income            Income of individuals in 2015
# 1014           Income             Income of households in 2015
# 1076           Income      Income of economic families in 2015
# 1681          Housing                        Core housing need
# 1912           Labour  Work activity during the reference year
# 1962  Journey to work                    Commuting destination
#
# Unique Category-Topic combinations where Cliffcrest is NaN:
#              Category                                    Topic
# 946            Income            Income of individuals in 2015
# 1014           Income             Income of households in 2015
# 1076           Income      Income of economic families in 2015
# 1681          Housing                        Core housing need
# 1912           Labour  Work activity during the reference year
# 1962  Journey to work                    Commuting destination
#
# Unique Category-Topic combinations where Corso Italia-Davenport is NaN:
#              Category                                    Topic
# 946            Income            Income of individuals in 2015
# 1014           Income             Income of households in 2015
# 1076           Income      Income of economic families in 2015
# 1681          Housing                        Core housing need
# 1912           Labour  Work activity during the reference year
# 1962  Journey to work                    Commuting destination
#
# Unique Category-Topic combinations where Danforth is NaN:
#              Category                                    Topic
# 946            Income            Income of individuals in 2015
# 1014           Income             Income of households in 2015
# 1076           Income      Income of economic families in 2015
# 1681          Housing                        Core housing need
# 1912           Labour  Work activity during the reference year
# 1962  Journey to work                    Commuting destination
#
# Unique Category-Topic combinations where Danforth East York is NaN:
#              Category                                    Topic
# 946            Income            Income of individuals in 2015
# 1014           Income             Income of households in 2015
# 1076           Income      Income of economic families in 2015
# 1681          Housing                        Core housing need
# 1912           Labour  Work activity during the reference year
# 1962  Journey to work                    Commuting destination
#
# Unique Category-Topic combinations where Don Valley Village is NaN:
#              Category                                    Topic
# 946            Income            Income of individuals in 2015
# 1014           Income             Income of households in 2015
# 1076           Income      Income of economic families in 2015
# 1681          Housing                        Core housing need
# 1912           Labour  Work activity during the reference year
# 1962  Journey to work                    Commuting destination
#
# Unique Category-Topic combinations where Dorset Park is NaN:
#              Category                                    Topic
# 946            Income            Income of individuals in 2015
# 1014           Income             Income of households in 2015
# 1076           Income      Income of economic families in 2015
# 1681          Housing                        Core housing need
# 1912           Labour  Work activity during the reference year
# 1962  Journey to work                    Commuting destination
#
# Unique Category-Topic combinations where Dovercourt-Wallace Emerson-Junction is NaN:
#              Category                                    Topic
# 946            Income            Income of individuals in 2015
# 1014           Income             Income of households in 2015
# 1076           Income      Income of economic families in 2015
# 1681          Housing                        Core housing need
# 1912           Labour  Work activity during the reference year
# 1962  Journey to work                    Commuting destination
#
# Unique Category-Topic combinations where Downsview-Roding-CFB is NaN:
#              Category                                    Topic
# 946            Income            Income of individuals in 2015
# 1014           Income             Income of households in 2015
# 1076           Income      Income of economic families in 2015
# 1681          Housing                        Core housing need
# 1912           Labour  Work activity during the reference year
# 1962  Journey to work                    Commuting destination
#
# Unique Category-Topic combinations where Dufferin Grove is NaN:
#              Category                                    Topic
# 946            Income            Income of individuals in 2015
# 1014           Income             Income of households in 2015
# 1076           Income      Income of economic families in 2015
# 1681          Housing                        Core housing need
# 1912           Labour  Work activity during the reference year
# 1962  Journey to work                    Commuting destination
#
# Unique Category-Topic combinations where East End-Danforth is NaN:
#              Category                                    Topic
# 946            Income            Income of individuals in 2015
# 1014           Income             Income of households in 2015
# 1076           Income      Income of economic families in 2015
# 1681          Housing                        Core housing need
# 1912           Labour  Work activity during the reference year
# 1962  Journey to work                    Commuting destination
#
# Unique Category-Topic combinations where Edenbridge-Humber Valley is NaN:
#              Category                                    Topic
# 946            Income            Income of individuals in 2015
# 1014           Income             Income of households in 2015
# 1076           Income      Income of economic families in 2015
# 1681          Housing                        Core housing need
# 1912           Labour  Work activity during the reference year
# 1962  Journey to work                    Commuting destination
#
# Unique Category-Topic combinations where Eglinton East is NaN:
#              Category                                    Topic
# 946            Income            Income of individuals in 2015
# 1014           Income             Income of households in 2015
# 1076           Income      Income of economic families in 2015
# 1681          Housing                        Core housing need
# 1912           Labour  Work activity during the reference year
# 1962  Journey to work                    Commuting destination
#
# Unique Category-Topic combinations where Elms-Old Rexdale is NaN:
#              Category                                    Topic
# 946            Income            Income of individuals in 2015
# 1014           Income             Income of households in 2015
# 1076           Income      Income of economic families in 2015
# 1681          Housing                        Core housing need
# 1912           Labour  Work activity during the reference year
# 1962  Journey to work                    Commuting destination
#
# Unique Category-Topic combinations where Englemount-Lawrence is NaN:
#              Category                                    Topic
# 946            Income            Income of individuals in 2015
# 1014           Income             Income of households in 2015
# 1076           Income      Income of economic families in 2015
# 1681          Housing                        Core housing need
# 1912           Labour  Work activity during the reference year
# 1962  Journey to work                    Commuting destination
#
# Unique Category-Topic combinations where Eringate-Centennial-West Deane is NaN:
#              Category                                    Topic
# 946            Income            Income of individuals in 2015
# 1014           Income             Income of households in 2015
# 1076           Income      Income of economic families in 2015
# 1681          Housing                        Core housing need
# 1912           Labour  Work activity during the reference year
# 1962  Journey to work                    Commuting destination
#
# Unique Category-Topic combinations where Etobicoke West Mall is NaN:
#              Category                                    Topic
# 946            Income            Income of individuals in 2015
# 1014           Income             Income of households in 2015
# 1076           Income      Income of economic families in 2015
# 1681          Housing                        Core housing need
# 1912           Labour  Work activity during the reference year
# 1962  Journey to work                    Commuting destination
#
# Unique Category-Topic combinations where Flemingdon Park is NaN:
#              Category                                    Topic
# 946            Income            Income of individuals in 2015
# 1014           Income             Income of households in 2015
# 1076           Income      Income of economic families in 2015
# 1681          Housing                        Core housing need
# 1912           Labour  Work activity during the reference year
# 1962  Journey to work                    Commuting destination
#
# Unique Category-Topic combinations where Forest Hill North is NaN:
#              Category                                    Topic
# 946            Income            Income of individuals in 2015
# 1014           Income             Income of households in 2015
# 1076           Income      Income of economic families in 2015
# 1681          Housing                        Core housing need
# 1912           Labour  Work activity during the reference year
# 1962  Journey to work                    Commuting destination
#
# Unique Category-Topic combinations where Forest Hill South is NaN:
#              Category                                    Topic
# 946            Income            Income of individuals in 2015
# 1014           Income             Income of households in 2015
# 1076           Income      Income of economic families in 2015
# 1681          Housing                        Core housing need
# 1912           Labour  Work activity during the reference year
# 1962  Journey to work                    Commuting destination
#
# Unique Category-Topic combinations where Glenfield-Jane Heights is NaN:
#              Category                                    Topic
# 946            Income            Income of individuals in 2015
# 1014           Income             Income of households in 2015
# 1076           Income      Income of economic families in 2015
# 1681          Housing                        Core housing need
# 1912           Labour  Work activity during the reference year
# 1962  Journey to work                    Commuting destination
#
# Unique Category-Topic combinations where Greenwood-Coxwell is NaN:
#              Category                                    Topic
# 946            Income            Income of individuals in 2015
# 1014           Income             Income of households in 2015
# 1076           Income      Income of economic families in 2015
# 1681          Housing                        Core housing need
# 1912           Labour  Work activity during the reference year
# 1962  Journey to work                    Commuting destination
#
# Unique Category-Topic combinations where Guildwood is NaN:
#              Category                                    Topic
# 946            Income            Income of individuals in 2015
# 1014           Income             Income of households in 2015
# 1076           Income      Income of economic families in 2015
# 1681          Housing                        Core housing need
# 1912           Labour  Work activity during the reference year
# 1962  Journey to work                    Commuting destination
#
# Unique Category-Topic combinations where Henry Farm is NaN:
#              Category                                    Topic
# 946            Income            Income of individuals in 2015
# 1014           Income             Income of households in 2015
# 1076           Income      Income of economic families in 2015
# 1681          Housing                        Core housing need
# 1912           Labour  Work activity during the reference year
# 1962  Journey to work                    Commuting destination
#
# Unique Category-Topic combinations where High Park North is NaN:
#              Category                                    Topic
# 946            Income            Income of individuals in 2015
# 1014           Income             Income of households in 2015
# 1076           Income      Income of economic families in 2015
# 1681          Housing                        Core housing need
# 1912           Labour  Work activity during the reference year
# 1962  Journey to work                    Commuting destination
#
# Unique Category-Topic combinations where High Park-Swansea is NaN:
#              Category                                    Topic
# 946            Income            Income of individuals in 2015
# 1014           Income             Income of households in 2015
# 1076           Income      Income of economic families in 2015
# 1681          Housing                        Core housing need
# 1912           Labour  Work activity during the reference year
# 1962  Journey to work                    Commuting destination
#
# Unique Category-Topic combinations where Highland Creek is NaN:
#              Category                                    Topic
# 946            Income            Income of individuals in 2015
# 1014           Income             Income of households in 2015
# 1076           Income      Income of economic families in 2015
# 1681          Housing                        Core housing need
# 1912           Labour  Work activity during the reference year
# 1962  Journey to work                    Commuting destination
#
# Unique Category-Topic combinations where Hillcrest Village is NaN:
#              Category                                    Topic
# 946            Income            Income of individuals in 2015
# 1014           Income             Income of households in 2015
# 1076           Income      Income of economic families in 2015
# 1681          Housing                        Core housing need
# 1912           Labour  Work activity during the reference year
# 1962  Journey to work                    Commuting destination
#
# Unique Category-Topic combinations where Humber Heights-Westmount is NaN:
#              Category                                    Topic
# 946            Income            Income of individuals in 2015
# 1014           Income             Income of households in 2015
# 1076           Income      Income of economic families in 2015
# 1681          Housing                        Core housing need
# 1912           Labour  Work activity during the reference year
# 1962  Journey to work                    Commuting destination
#
# Unique Category-Topic combinations where Humber Summit is NaN:
#              Category                                    Topic
# 946            Income            Income of individuals in 2015
# 1014           Income             Income of households in 2015
# 1076           Income      Income of economic families in 2015
# 1681          Housing                        Core housing need
# 1912           Labour  Work activity during the reference year
# 1962  Journey to work                    Commuting destination
#
# Unique Category-Topic combinations where Humbermede is NaN:
#              Category                                    Topic
# 946            Income            Income of individuals in 2015
# 1014           Income             Income of households in 2015
# 1076           Income      Income of economic families in 2015
# 1681          Housing                        Core housing need
# 1912           Labour  Work activity during the reference year
# 1962  Journey to work                    Commuting destination
#
# Unique Category-Topic combinations where Humewood-Cedarvale is NaN:
#              Category                                    Topic
# 946            Income            Income of individuals in 2015
# 1014           Income             Income of households in 2015
# 1076           Income      Income of economic families in 2015
# 1681          Housing                        Core housing need
# 1912           Labour  Work activity during the reference year
# 1962  Journey to work                    Commuting destination
#
# Unique Category-Topic combinations where Ionview is NaN:
#              Category                                    Topic
# 946            Income            Income of individuals in 2015
# 1014           Income             Income of households in 2015
# 1076           Income      Income of economic families in 2015
# 1681          Housing                        Core housing need
# 1912           Labour  Work activity during the reference year
# 1962  Journey to work                    Commuting destination
#
# Unique Category-Topic combinations where Islington-City Centre West is NaN:
#              Category                                    Topic
# 946            Income            Income of individuals in 2015
# 1014           Income             Income of households in 2015
# 1076           Income      Income of economic families in 2015
# 1681          Housing                        Core housing need
# 1912           Labour  Work activity during the reference year
# 1962  Journey to work                    Commuting destination
#
# Unique Category-Topic combinations where Junction Area is NaN:
#              Category                                    Topic
# 946            Income            Income of individuals in 2015
# 1014           Income             Income of households in 2015
# 1076           Income      Income of economic families in 2015
# 1681          Housing                        Core housing need
# 1912           Labour  Work activity during the reference year
# 1962  Journey to work                    Commuting destination
#
# Unique Category-Topic combinations where Keelesdale-Eglinton West is NaN:
#              Category                                    Topic
# 946            Income            Income of individuals in 2015
# 1014           Income             Income of households in 2015
# 1076           Income      Income of economic families in 2015
# 1681          Housing                        Core housing need
# 1912           Labour  Work activity during the reference year
# 1962  Journey to work                    Commuting destination
#
# Unique Category-Topic combinations where Kennedy Park is NaN:
#              Category                                    Topic
# 946            Income            Income of individuals in 2015
# 1014           Income             Income of households in 2015
# 1076           Income      Income of economic families in 2015
# 1681          Housing                        Core housing need
# 1912           Labour  Work activity during the reference year
# 1962  Journey to work                    Commuting destination
#
# Unique Category-Topic combinations where Kensington-Chinatown is NaN:
#              Category                                    Topic
# 946            Income            Income of individuals in 2015
# 1014           Income             Income of households in 2015
# 1076           Income      Income of economic families in 2015
# 1681          Housing                        Core housing need
# 1912           Labour  Work activity during the reference year
# 1962  Journey to work                    Commuting destination
#
# Unique Category-Topic combinations where Kingsview Village-The Westway is NaN:
#              Category                                    Topic
# 946            Income            Income of individuals in 2015
# 1014           Income             Income of households in 2015
# 1076           Income      Income of economic families in 2015
# 1681          Housing                        Core housing need
# 1912           Labour  Work activity during the reference year
# 1962  Journey to work                    Commuting destination
#
# Unique Category-Topic combinations where Kingsway South is NaN:
#              Category                                    Topic
# 946            Income            Income of individuals in 2015
# 1014           Income             Income of households in 2015
# 1076           Income      Income of economic families in 2015
# 1681          Housing                        Core housing need
# 1912           Labour  Work activity during the reference year
# 1962  Journey to work                    Commuting destination
#
# Unique Category-Topic combinations where Lambton Baby Point is NaN:
#              Category                                    Topic
# 946            Income            Income of individuals in 2015
# 1014           Income             Income of households in 2015
# 1076           Income      Income of economic families in 2015
# 1681          Housing                        Core housing need
# 1912           Labour  Work activity during the reference year
# 1962  Journey to work                    Commuting destination
#
# Unique Category-Topic combinations where L'Amoreaux is NaN:
#              Category                                    Topic
# 946            Income            Income of individuals in 2015
# 1014           Income             Income of households in 2015
# 1076           Income      Income of economic families in 2015
# 1681          Housing                        Core housing need
# 1912           Labour  Work activity during the reference year
# 1962  Journey to work                    Commuting destination
#
# Unique Category-Topic combinations where Lansing-Westgate is NaN:
#              Category                                    Topic
# 946            Income            Income of individuals in 2015
# 1014           Income             Income of households in 2015
# 1076           Income      Income of economic families in 2015
# 1681          Housing                        Core housing need
# 1912           Labour  Work activity during the reference year
# 1962  Journey to work                    Commuting destination
#
# Unique Category-Topic combinations where Lawrence Park North is NaN:
#              Category                                    Topic
# 946            Income            Income of individuals in 2015
# 1014           Income             Income of households in 2015
# 1076           Income      Income of economic families in 2015
# 1681          Housing                        Core housing need
# 1912           Labour  Work activity during the reference year
# 1962  Journey to work                    Commuting destination
#
# Unique Category-Topic combinations where Lawrence Park South is NaN:
#              Category                                    Topic
# 946            Income            Income of individuals in 2015
# 1014           Income             Income of households in 2015
# 1076           Income      Income of economic families in 2015
# 1681          Housing                        Core housing need
# 1912           Labour  Work activity during the reference year
# 1962  Journey to work                    Commuting destination
#
# Unique Category-Topic combinations where Leaside-Bennington is NaN:
#              Category                                    Topic
# 946            Income            Income of individuals in 2015
# 1014           Income             Income of households in 2015
# 1076           Income      Income of economic families in 2015
# 1681          Housing                        Core housing need
# 1912           Labour  Work activity during the reference year
# 1962  Journey to work                    Commuting destination
#
# Unique Category-Topic combinations where Little Portugal is NaN:
#              Category                                    Topic
# 946            Income            Income of individuals in 2015
# 1014           Income             Income of households in 2015
# 1076           Income      Income of economic families in 2015
# 1681          Housing                        Core housing need
# 1912           Labour  Work activity during the reference year
# 1962  Journey to work                    Commuting destination
#
# Unique Category-Topic combinations where Long Branch is NaN:
#              Category                                    Topic
# 946            Income            Income of individuals in 2015
# 1014           Income             Income of households in 2015
# 1076           Income      Income of economic families in 2015
# 1681          Housing                        Core housing need
# 1912           Labour  Work activity during the reference year
# 1962  Journey to work                    Commuting destination
#
# Unique Category-Topic combinations where Malvern is NaN:
#              Category                                    Topic
# 946            Income            Income of individuals in 2015
# 1014           Income             Income of households in 2015
# 1076           Income      Income of economic families in 2015
# 1681          Housing                        Core housing need
# 1912           Labour  Work activity during the reference year
# 1962  Journey to work                    Commuting destination
#
# Unique Category-Topic combinations where Maple Leaf is NaN:
#              Category                                    Topic
# 946            Income            Income of individuals in 2015
# 1014           Income             Income of households in 2015
# 1076           Income      Income of economic families in 2015
# 1681          Housing                        Core housing need
# 1912           Labour  Work activity during the reference year
# 1962  Journey to work                    Commuting destination
#
# Unique Category-Topic combinations where Markland Wood is NaN:
#              Category                                    Topic
# 946            Income            Income of individuals in 2015
# 1014           Income             Income of households in 2015
# 1076           Income      Income of economic families in 2015
# 1681          Housing                        Core housing need
# 1912           Labour  Work activity during the reference year
# 1962  Journey to work                    Commuting destination
#
# Unique Category-Topic combinations where Milliken is NaN:
#              Category                                    Topic
# 946            Income            Income of individuals in 2015
# 1014           Income             Income of households in 2015
# 1076           Income      Income of economic families in 2015
# 1681          Housing                        Core housing need
# 1912           Labour  Work activity during the reference year
# 1962  Journey to work                    Commuting destination
#
# Unique Category-Topic combinations where Mimico (includes Humber Bay Shores) is NaN:
#              Category                                    Topic
# 946            Income            Income of individuals in 2015
# 1014           Income             Income of households in 2015
# 1076           Income      Income of economic families in 2015
# 1681          Housing                        Core housing need
# 1912           Labour  Work activity during the reference year
# 1962  Journey to work                    Commuting destination
#
# Unique Category-Topic combinations where Morningside is NaN:
#              Category                                    Topic
# 946            Income            Income of individuals in 2015
# 1014           Income             Income of households in 2015
# 1076           Income      Income of economic families in 2015
# 1681          Housing                        Core housing need
# 1912           Labour  Work activity during the reference year
# 1962  Journey to work                    Commuting destination
#
# Unique Category-Topic combinations where Moss Park is NaN:
#              Category                                    Topic
# 946            Income            Income of individuals in 2015
# 1014           Income             Income of households in 2015
# 1076           Income      Income of economic families in 2015
# 1681          Housing                        Core housing need
# 1912           Labour  Work activity during the reference year
# 1962  Journey to work                    Commuting destination
#
# Unique Category-Topic combinations where Mount Dennis is NaN:
#              Category                                    Topic
# 946            Income            Income of individuals in 2015
# 1014           Income             Income of households in 2015
# 1076           Income      Income of economic families in 2015
# 1681          Housing                        Core housing need
# 1912           Labour  Work activity during the reference year
# 1962  Journey to work                    Commuting destination
#
# Unique Category-Topic combinations where Mount Olive-Silverstone-Jamestown is NaN:
#              Category                                    Topic
# 946            Income            Income of individuals in 2015
# 1014           Income             Income of households in 2015
# 1076           Income      Income of economic families in 2015
# 1681          Housing                        Core housing need
# 1912           Labour  Work activity during the reference year
# 1962  Journey to work                    Commuting destination
#
# Unique Category-Topic combinations where Mount Pleasant East is NaN:
#              Category                                    Topic
# 946            Income            Income of individuals in 2015
# 1014           Income             Income of households in 2015
# 1076           Income      Income of economic families in 2015
# 1681          Housing                        Core housing need
# 1912           Labour  Work activity during the reference year
# 1962  Journey to work                    Commuting destination
#
# Unique Category-Topic combinations where Mount Pleasant West is NaN:
#              Category                                    Topic
# 946            Income            Income of individuals in 2015
# 1014           Income             Income of households in 2015
# 1076           Income      Income of economic families in 2015
# 1681          Housing                        Core housing need
# 1912           Labour  Work activity during the reference year
# 1962  Journey to work                    Commuting destination
#
# Unique Category-Topic combinations where New Toronto is NaN:
#              Category                                    Topic
# 946            Income            Income of individuals in 2015
# 1014           Income             Income of households in 2015
# 1076           Income      Income of economic families in 2015
# 1681          Housing                        Core housing need
# 1912           Labour  Work activity during the reference year
# 1962  Journey to work                    Commuting destination
#
# Unique Category-Topic combinations where Newtonbrook East is NaN:
#              Category                                    Topic
# 946            Income            Income of individuals in 2015
# 1014           Income             Income of households in 2015
# 1076           Income      Income of economic families in 2015
# 1681          Housing                        Core housing need
# 1912           Labour  Work activity during the reference year
# 1962  Journey to work                    Commuting destination
#
# Unique Category-Topic combinations where Newtonbrook West is NaN:
#              Category                                    Topic
# 946            Income            Income of individuals in 2015
# 1014           Income             Income of households in 2015
# 1076           Income      Income of economic families in 2015
# 1681          Housing                        Core housing need
# 1912           Labour  Work activity during the reference year
# 1962  Journey to work                    Commuting destination
#
# Unique Category-Topic combinations where Niagara is NaN:
#              Category                                    Topic
# 946            Income            Income of individuals in 2015
# 1014           Income             Income of households in 2015
# 1076           Income      Income of economic families in 2015
# 1681          Housing                        Core housing need
# 1912           Labour  Work activity during the reference year
# 1962  Journey to work                    Commuting destination
#
# Unique Category-Topic combinations where North Riverdale is NaN:
#              Category                                    Topic
# 946            Income            Income of individuals in 2015
# 1014           Income             Income of households in 2015
# 1076           Income      Income of economic families in 2015
# 1681          Housing                        Core housing need
# 1912           Labour  Work activity during the reference year
# 1962  Journey to work                    Commuting destination
#
# Unique Category-Topic combinations where North St. James Town is NaN:
#              Category                                    Topic
# 946            Income            Income of individuals in 2015
# 1014           Income             Income of households in 2015
# 1076           Income      Income of economic families in 2015
# 1681          Housing                        Core housing need
# 1912           Labour  Work activity during the reference year
# 1962  Journey to work                    Commuting destination
#
# Unique Category-Topic combinations where Oakridge is NaN:
#              Category                                    Topic
# 946            Income            Income of individuals in 2015
# 1014           Income             Income of households in 2015
# 1076           Income      Income of economic families in 2015
# 1681          Housing                        Core housing need
# 1912           Labour  Work activity during the reference year
# 1962  Journey to work                    Commuting destination
#
# Unique Category-Topic combinations where Oakwood Village is NaN:
#              Category                                    Topic
# 946            Income            Income of individuals in 2015
# 1014           Income             Income of households in 2015
# 1076           Income      Income of economic families in 2015
# 1681          Housing                        Core housing need
# 1912           Labour  Work activity during the reference year
# 1962  Journey to work                    Commuting destination
#
# Unique Category-Topic combinations where O'Connor-Parkview is NaN:
#              Category                                    Topic
# 946            Income            Income of individuals in 2015
# 1014           Income             Income of households in 2015
# 1076           Income      Income of economic families in 2015
# 1681          Housing                        Core housing need
# 1912           Labour  Work activity during the reference year
# 1962  Journey to work                    Commuting destination
#
# ...
# 1681          Housing                        Core housing need
# 1912           Labour  Work activity during the reference year
# 1962  Journey to work                    Commuting destination
#
# Unique Category-Topic combinations where South Parkdale is NaN:
#              Category                                    Topic
# 946            Income            Income of individuals in 2015
# 1014           Income             Income of households in 2015
# 1076           Income      Income of economic families in 2015
# 1681          Housing                        Core housing need
# 1912           Labour  Work activity during the reference year
# 1962  Journey to work                    Commuting destination
#
# Unique Category-Topic combinations where South Riverdale is NaN:
#              Category                                    Topic
# 946            Income            Income of individuals in 2015
# 1014           Income             Income of households in 2015
# 1076           Income      Income of economic families in 2015
# 1681          Housing                        Core housing need
# 1912           Labour  Work activity during the reference year
# 1962  Journey to work                    Commuting destination
#
# Unique Category-Topic combinations where St.Andrew-Windfields is NaN:
#              Category                                    Topic
# 946            Income            Income of individuals in 2015
# 1014           Income             Income of households in 2015
# 1076           Income      Income of economic families in 2015
# 1681          Housing                        Core housing need
# 1912           Labour  Work activity during the reference year
# 1962  Journey to work                    Commuting destination
#
# Unique Category-Topic combinations where Steeles is NaN:
#              Category                                    Topic
# 946            Income            Income of individuals in 2015
# 1014           Income             Income of households in 2015
# 1076           Income      Income of economic families in 2015
# 1681          Housing                        Core housing need
# 1912           Labour  Work activity during the reference year
# 1962  Journey to work                    Commuting destination
#
# Unique Category-Topic combinations where Stonegate-Queensway is NaN:
#              Category                                    Topic
# 946            Income            Income of individuals in 2015
# 1014           Income             Income of households in 2015
# 1076           Income      Income of economic families in 2015
# 1681          Housing                        Core housing need
# 1912           Labour  Work activity during the reference year
# 1962  Journey to work                    Commuting destination
#
# Unique Category-Topic combinations where Tam O'Shanter-Sullivan is NaN:
#              Category                                    Topic
# 946            Income            Income of individuals in 2015
# 1014           Income             Income of households in 2015
# 1076           Income      Income of economic families in 2015
# 1681          Housing                        Core housing need
# 1912           Labour  Work activity during the reference year
# 1962  Journey to work                    Commuting destination
#
# Unique Category-Topic combinations where Taylor-Massey is NaN:
#              Category                                    Topic
# 946            Income            Income of individuals in 2015
# 1014           Income             Income of households in 2015
# 1076           Income      Income of economic families in 2015
# 1681          Housing                        Core housing need
# 1912           Labour  Work activity during the reference year
# 1962  Journey to work                    Commuting destination
#
# Unique Category-Topic combinations where The Beaches is NaN:
#              Category                                    Topic
# 946            Income            Income of individuals in 2015
# 1014           Income             Income of households in 2015
# 1076           Income      Income of economic families in 2015
# 1681          Housing                        Core housing need
# 1912           Labour  Work activity during the reference year
# 1962  Journey to work                    Commuting destination
#
# Unique Category-Topic combinations where Thistletown-Beaumond Heights is NaN:
#              Category                                    Topic
# 946            Income            Income of individuals in 2015
# 1014           Income             Income of households in 2015
# 1076           Income      Income of economic families in 2015
# 1681          Housing                        Core housing need
# 1912           Labour  Work activity during the reference year
# 1962  Journey to work                    Commuting destination
#
# Unique Category-Topic combinations where Thorncliffe Park is NaN:
#              Category                                    Topic
# 946            Income            Income of individuals in 2015
# 1014           Income             Income of households in 2015
# 1076           Income      Income of economic families in 2015
# 1681          Housing                        Core housing need
# 1912           Labour  Work activity during the reference year
# 1962  Journey to work                    Commuting destination
#
# Unique Category-Topic combinations where Trinity-Bellwoods is NaN:
#              Category                                    Topic
# 946            Income            Income of individuals in 2015
# 1014           Income             Income of households in 2015
# 1076           Income      Income of economic families in 2015
# 1681          Housing                        Core housing need
# 1912           Labour  Work activity during the reference year
# 1962  Journey to work                    Commuting destination
#
# Unique Category-Topic combinations where University is NaN:
#              Category                                    Topic
# 946            Income            Income of individuals in 2015
# 1014           Income             Income of households in 2015
# 1076           Income      Income of economic families in 2015
# 1681          Housing                        Core housing need
# 1912           Labour  Work activity during the reference year
# 1962  Journey to work                    Commuting destination
#
# Unique Category-Topic combinations where Victoria Village is NaN:
#              Category                                    Topic
# 946            Income            Income of individuals in 2015
# 1014           Income             Income of households in 2015
# 1076           Income      Income of economic families in 2015
# 1681          Housing                        Core housing need
# 1912           Labour  Work activity during the reference year
# 1962  Journey to work                    Commuting destination
#
# Unique Category-Topic combinations where Waterfront Communities-The Island is NaN:
#              Category                                    Topic
# 946            Income            Income of individuals in 2015
# 1014           Income             Income of households in 2015
# 1076           Income      Income of economic families in 2015
# 1681          Housing                        Core housing need
# 1912           Labour  Work activity during the reference year
# 1962  Journey to work                    Commuting destination
#
# Unique Category-Topic combinations where West Hill is NaN:
#              Category                                    Topic
# 946            Income            Income of individuals in 2015
# 1014           Income             Income of households in 2015
# 1076           Income      Income of economic families in 2015
# 1681          Housing                        Core housing need
# 1912           Labour  Work activity during the reference year
# 1962  Journey to work                    Commuting destination
#
# Unique Category-Topic combinations where West Humber-Clairville is NaN:
#              Category                                    Topic
# 946            Income            Income of individuals in 2015
# 1014           Income             Income of households in 2015
# 1076           Income      Income of economic families in 2015
# 1681          Housing                        Core housing need
# 1912           Labour  Work activity during the reference year
# 1962  Journey to work                    Commuting destination
#
# Unique Category-Topic combinations where Westminster-Branson is NaN:
#              Category                                    Topic
# 946            Income            Income of individuals in 2015
# 1014           Income             Income of households in 2015
# 1076           Income      Income of economic families in 2015
# 1681          Housing                        Core housing need
# 1912           Labour  Work activity during the reference year
# 1962  Journey to work                    Commuting destination
#
# Unique Category-Topic combinations where Weston is NaN:
#              Category                                    Topic
# 946            Income            Income of individuals in 2015
# 1014           Income             Income of households in 2015
# 1076           Income      Income of economic families in 2015
# 1681          Housing                        Core housing need
# 1912           Labour  Work activity during the reference year
# 1962  Journey to work                    Commuting destination
#
# Unique Category-Topic combinations where Weston-Pelham Park is NaN:
#              Category                                    Topic
# 946            Income            Income of individuals in 2015
# 1014           Income             Income of households in 2015
# 1076           Income      Income of economic families in 2015
# 1681          Housing                        Core housing need
# 1912           Labour  Work activity during the reference year
# 1962  Journey to work                    Commuting destination
#
# Unique Category-Topic combinations where Wexford/Maryvale is NaN:
#              Category                                    Topic
# 946            Income            Income of individuals in 2015
# 1014           Income             Income of households in 2015
# 1076           Income      Income of economic families in 2015
# 1681          Housing                        Core housing need
# 1912           Labour  Work activity during the reference year
# 1962  Journey to work                    Commuting destination
#
# Unique Category-Topic combinations where Willowdale East is NaN:
#              Category                                    Topic
# 946            Income            Income of individuals in 2015
# 1014           Income             Income of households in 2015
# 1076           Income      Income of economic families in 2015
# 1681          Housing                        Core housing need
# 1912           Labour  Work activity during the reference year
# 1962  Journey to work                    Commuting destination
#
# Unique Category-Topic combinations where Willowdale West is NaN:
#              Category                                    Topic
# 946            Income            Income of individuals in 2015
# 1014           Income             Income of households in 2015
# 1076           Income      Income of economic families in 2015
# 1681          Housing                        Core housing need
# 1912           Labour  Work activity during the reference year
# 1962  Journey to work                    Commuting destination
#
# Unique Category-Topic combinations where Willowridge-Martingrove-Richview is NaN:
#              Category                                    Topic
# 946            Income            Income of individuals in 2015
# 1014           Income             Income of households in 2015
# 1076           Income      Income of economic families in 2015
# 1681          Housing                        Core housing need
# 1912           Labour  Work activity during the reference year
# 1962  Journey to work                    Commuting destination
#
# Unique Category-Topic combinations where Woburn is NaN:
#              Category                                    Topic
# 946            Income            Income of individuals in 2015
# 1014           Income             Income of households in 2015
# 1076           Income      Income of economic families in 2015
# 1681          Housing                        Core housing need
# 1912           Labour  Work activity during the reference year
# 1962  Journey to work                    Commuting destination
#
# Unique Category-Topic combinations where Woodbine Corridor is NaN:
#              Category                                    Topic
# 946            Income            Income of individuals in 2015
# 1014           Income             Income of households in 2015
# 1076           Income      Income of economic families in 2015
# 1681          Housing                        Core housing need
# 1912           Labour  Work activity during the reference year
# 1962  Journey to work                    Commuting destination
#
# Unique Category-Topic combinations where Woodbine-Lumsden is NaN:
#              Category                                    Topic
# 946            Income            Income of individuals in 2015
# 1014           Income             Income of households in 2015
# 1076           Income      Income of economic families in 2015
# 1681          Housing                        Core housing need
# 1912           Labour  Work activity during the reference year
# 1962  Journey to work                    Commuting destination
#
# Unique Category-Topic combinations where Wychwood is NaN:
#              Category                                    Topic
# 946            Income            Income of individuals in 2015
# 1014           Income             Income of households in 2015
# 1076           Income      Income of economic families in 2015
# 1681          Housing                        Core housing need
# 1912           Labour  Work activity during the reference year
# 1962  Journey to work                    Commuting destination
#
# Unique Category-Topic combinations where Yonge-Eglinton is NaN:
#              Category                                    Topic
# 946            Income            Income of individuals in 2015
# 1014           Income             Income of households in 2015
# 1076           Income      Income of economic families in 2015
# 1681          Housing                        Core housing need
# 1912           Labour  Work activity during the reference year
# 1962  Journey to work                    Commuting destination
#
# Unique Category-Topic combinations where Yonge-St.Clair is NaN:
#              Category                                    Topic
# 946            Income            Income of individuals in 2015
# 1014           Income             Income of households in 2015
# 1076           Income      Income of economic families in 2015
# 1681          Housing                        Core housing need
# 1912           Labour  Work activity during the reference year
# 1962  Journey to work                    Commuting destination
#
# Unique Category-Topic combinations where York University Heights is NaN:
#              Category                                    Topic
# 946            Income            Income of individuals in 2015
# 1014           Income             Income of households in 2015
# 1076           Income      Income of economic families in 2015
# 1681          Housing                        Core housing need
# 1912           Labour  Work activity during the reference year
# 1962  Journey to work                    Commuting destination
#
# Unique Category-Topic combinations where Yorkdale-Glen Park is NaN:
#              Category                                    Topic
# 946            Income            Income of individuals in 2015
# 1014           Income             Income of households in 2015
# 1076           Income      Income of economic families in 2015
# 1681          Housing                        Core housing need
# 1912           Labour  Work activity during the reference year
# 1962  Journey to work                    Commuting destination

# %%
selected_row = {
  "Income of households in 2015": ["Average after-tax income of households in 2015 ($)"],
  "Mother tongue": [],
  "Immigrants by selected place of birth": [],
  "Population and dwellings": ["Land area in square kilometres"]
}

# %%
# stripe profile_df Characteristic and Topic
profile_df['Characteristic'] = profile_df['Characteristic'].str.strip()
profile_df['Topic'] = profile_df['Topic'].str.strip()

# %%
# Create a mask for filtering based on selected_row criteria
masks = []

for topic, characteristics in selected_row.items():
    if topic == "Mother tongue":
        # profile_df['Characteristic'] should not start from space
        topic_mask = (profile_df['Topic'] == topic) & ~(profile_df['Characteristic'].str.endswith('n.i.e.') | profile_df['Characteristic'].str.endswith('n.o.s.'))
    elif characteristics:  # If the list is not empty
        # Filter rows where Topic matches and Characteristic is in the list
        topic_mask = (profile_df['Topic'] == topic) & (profile_df['Characteristic'].isin(characteristics))
    else:
        # If list is empty, just match the Topic
        topic_mask = (profile_df['Topic'] == topic)
    masks.append(topic_mask)

# Combine all masks with OR operation
final_mask = pd.concat(masks, axis=0).groupby(level=0).any()

# Apply the mask to filter the DataFrame
filtered_profile_df = profile_df[final_mask]

filtered_profile_df.head()
# Out:
#      _id    Category                     Topic  \
# 8      9  Population  Population and dwellings
# 139  140    Language             Mother tongue
# 140  141    Language             Mother tongue
# 141  142    Language             Mother tongue
# 142  143    Language             Mother tongue
#
#                         Data Source  \
# 8    Census Profile 98-316-X2016001
# 139  Census Profile 98-316-X2016001
# 140  Census Profile 98-316-X2016001
# 141  Census Profile 98-316-X2016001
# 142  Census Profile 98-316-X2016001
#
#                                         Characteristic City of Toronto  \
# 8                       Land area in square kilometres           630.2
# 139  Mother tongue for the total population excludi...       2,704,415
# 140                                   Single responses       2,598,230
# 141                                 Official languages       1,411,345
# 142                                            English       1,375,905
#
#     Agincourt North Agincourt South-Malvern West Alderwood   Annex  ...  \
# 8              7.41                         7.83      4.95    2.81  ...
# 139          28,845                       23,740    12,035  29,880  ...
# 140          27,740                       22,720    11,675  29,110  ...
# 141           7,185                        7,215     7,465  21,355  ...
# 142           7,070                        7,080     7,360  20,645  ...
#
#     Willowdale West Willowridge-Martingrove-Richview  Woburn  \
# 8              2.91                             5.53   12.31
# 139          16,890                           22,150  53,310
# 140          16,320                           21,270  50,360
# 141           5,925                           11,745  23,050
# 142           5,785                           11,470  22,645
#
#     Woodbine Corridor Woodbine-Lumsden Wychwood Yonge-Eglinton Yonge-St.Clair  \
# 8                 1.6             1.17     1.68           1.65           1.17
# 139            12,445            7,845   13,345         11,810         12,530
# 140            12,185            7,650   12,925         11,495         12,240
# 141             9,840            5,530    8,680          8,720          9,480
# 142             9,515            5,405    8,445          8,485          9,230
#
#     York University Heights Yorkdale-Glen Park
# 8                     13.23               6.04
# 139                  27,590             14,050
# 140                  26,190             13,395
# 141                  11,590              6,000
# 142                  11,385              5,900
#
# [5 rows x 146 columns]

# %%
# 获取需要处理的列（从第6列开始）
value_columns = filtered_profile_df.columns[5:]

# 定义函数来转换字符串为数值
def convert_to_numeric(x):
    if pd.isna(x):  # 处理空值
        return x
    # 移除千位分隔符
    if isinstance(x, str):
        x = x.replace(',', '')
    # 转换为float
    try:
        return float(x)
    except:
        return x

# 应用转换到所有数值列
for col in value_columns:
    filtered_profile_df[col] = filtered_profile_df[col].apply(convert_to_numeric)

filtered_profile_df.head()
# Out:
# /var/folders/wk/z0kty8ys5b577hxw6tf6659c0000gn/T/ipykernel_21558/459504010.py:19: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   filtered_profile_df[col] = filtered_profile_df[col].apply(convert_to_numeric)
#      _id    Category                     Topic  \
# 8      9  Population  Population and dwellings
# 139  140    Language             Mother tongue
# 140  141    Language             Mother tongue
# 141  142    Language             Mother tongue
# 142  143    Language             Mother tongue
#
#                         Data Source  \
# 8    Census Profile 98-316-X2016001
# 139  Census Profile 98-316-X2016001
# 140  Census Profile 98-316-X2016001
# 141  Census Profile 98-316-X2016001
# 142  Census Profile 98-316-X2016001
#
#                                         Characteristic  City of Toronto  \
# 8                       Land area in square kilometres            630.2
# 139  Mother tongue for the total population excludi...        2704415.0
# 140                                   Single responses        2598230.0
# 141                                 Official languages        1411345.0
# 142                                            English        1375905.0
#
#      Agincourt North  Agincourt South-Malvern West  Alderwood     Annex  ...  \
# 8               7.41                          7.83       4.95      2.81  ...
# 139         28845.00                      23740.00   12035.00  29880.00  ...
# 140         27740.00                      22720.00   11675.00  29110.00  ...
# 141          7185.00                       7215.00    7465.00  21355.00  ...
# 142          7070.00                       7080.00    7360.00  20645.00  ...
#
#      Willowdale West  Willowridge-Martingrove-Richview    Woburn  \
# 8               2.91                              5.53     12.31
# 139         16890.00                          22150.00  53310.00
# 140         16320.00                          21270.00  50360.00
# 141          5925.00                          11745.00  23050.00
# 142          5785.00                          11470.00  22645.00
#
#      Woodbine Corridor  Woodbine-Lumsden  Wychwood  Yonge-Eglinton  \
# 8                  1.6              1.17      1.68            1.65
# 139            12445.0           7845.00  13345.00        11810.00
# 140            12185.0           7650.00  12925.00        11495.00
# 141             9840.0           5530.00   8680.00         8720.00
# 142             9515.0           5405.00   8445.00         8485.00
#
#      Yonge-St.Clair  York University Heights  Yorkdale-Glen Park
# 8              1.17                    13.23                6.04
# 139        12530.00                 27590.00            14050.00
# 140        12240.00                 26190.00            13395.00
# 141         9480.00                 11590.00             6000.00
# 142         9230.00                 11385.00             5900.00
#
# [5 rows x 146 columns]

# %%
# Count NaN values for each column
nan_counts = filtered_profile_df.isna().sum()

# Show only columns that have NaN values (if any)
columns_with_nans = nan_counts[nan_counts > 0]
print("Columns with NaN values:")
print(columns_with_nans)

# For columns with NaN values, show unique Category-Topic combinations
if len(columns_with_nans) > 0:
    for col in columns_with_nans.index:
        print(f"\nUnique Category-Topic combinations where {col} is NaN:")
        unique_combinations = filtered_profile_df[filtered_profile_df[col].isna()][['Category', 'Topic']].drop_duplicates()
        print(unique_combinations)
# Out:
# Columns with NaN values:
# Series([], dtype: int64)

# %%
neighbourhoods = filtered_profile_df.columns[5:]
base_cols = ['_id', 'Category', 'Topic', 'Data Source', 'Characteristic']

def revert_table_direction(df):
    melted_df = pd.melt(
        df,
        id_vars=base_cols,
        value_vars=neighbourhoods,
        var_name='neighbourhood',
        value_name='value'
    )

    pivoted_df = melted_df.pivot(
        index=['neighbourhood'],
        columns='Characteristic',
        values='value'
    ).reset_index()

    pivoted_df.columns.name = None

    return pivoted_df

# %%
# language df and calculate shannon entropy

language_df = filtered_profile_df[filtered_profile_df['Topic'] == 'Mother tongue']
language_df = revert_table_direction(language_df)

def calculate_shannon_entropy(row):
    """
    Calculate Shannon Entropy for a row of language data.
    Higher values indicate more diversity.
    """
    # Get the total population from the specific column
    total_population = row['Mother tongue for the total population excluding institutional residents']
    
    # Remove non-language columns and convert to numpy array
    values = row.drop(['neighbourhood', 'Mother tongue for the total population excluding institutional residents']).values.astype(float)
    
    # Avoid division by zero
    if total_population == 0:
        return 0
    
    # Calculate proportions using the total population
    proportions = values / total_population
    
    # Remove zeros to avoid log(0)
    proportions = proportions[proportions > 0]
    
    # Calculate Shannon entropy
    entropy = -np.sum(proportions * np.log(proportions))
    
    return entropy

# Calculate Shannon Entropy for each neighborhood
diversity_scores = pd.DataFrame()
diversity_scores['neighbourhood'] = language_df['neighbourhood']
diversity_scores['total_language_population'] = language_df['Mother tongue for the total population excluding institutional residents'].astype(int)
diversity_scores['shannon_diversity'] = language_df.apply(calculate_shannon_entropy, axis=1)

# Sort by diversity score in descending order
diversity_scores = diversity_scores.sort_values('shannon_diversity', ascending=False)

# Display results
print("\nCultural Diversity Scores (Shannon Entropy):")
print("\nTop 10 Most Diverse Neighborhoods:")
print(diversity_scores[['neighbourhood', 'total_language_population', 'shannon_diversity']].head(10))

print("\nBottom 10 Least Diverse Neighborhoods:")
print(diversity_scores[['neighbourhood', 'total_language_population', 'shannon_diversity']].tail(10))

# Calculate summary statistics
print("\nSummary Statistics of Diversity Scores:")
print(diversity_scores['shannon_diversity'].describe())

# Save results to CSV
# diversity_scores.to_csv('../static/data/processed/language_diversity_scores.csv', index=False)
# Out:
# Cultural Diversity Scores (Shannon Entropy):
#
# Top 10 Most Diverse Neighborhoods:
#                          neighbourhood  total_language_population  \
# 43                     Flemingdon Park                      21930
# 49                          Henry Farm                      15725
# 31                  Don Valley Village                      26850
# 87                    Newtonbrook West                      23640
# 90                North St. James Town                      18405
# 139            York University Heights                      27590
# 64       Kingsview Village-The Westway                      21990
# 32                         Dorset Park                      24395
# 119                   Thorncliffe Park                      20850
# 82   Mount Olive-Silverstone-Jamestown                      32825
#
#      shannon_diversity
# 43            6.944351
# 49            6.768657
# 31            6.617282
# 87            6.467129
# 90            6.457026
# 139           6.297548
# 64            6.225959
# 32            6.199430
# 119           6.165640
# 82            6.165493
#
# Bottom 10 Least Diverse Neighborhoods:
#                 neighbourhood  total_language_population  shannon_diversity
# 105       Rosedale-Moore Park                      20900           3.675876
# 21                  Casa Loma                      10870           3.668798
# 98   Playter Estates-Danforth                       7755           3.575880
# 65             Kingsway South                       9275           3.539810
# 89            North Riverdale                      11700           3.507829
# 134         Woodbine Corridor                      12445           3.497755
# 69        Lawrence Park North                      14605           3.476611
# 70        Lawrence Park South                      15185           3.276663
# 71         Leaside-Bennington                      16690           3.114189
# 117               The Beaches                      21530           2.514812
#
# Summary Statistics of Diversity Scores:
# count    141.000000
# mean       5.113066
# std        0.855784
# min        2.514812
# 25%        4.535250
# 50%        5.204533
# 75%        5.766219
# max        6.944351
# Name: shannon_diversity, dtype: float64

# %%
# add land area to diversity_scores
land_area_df = filtered_profile_df[filtered_profile_df['Topic'] == 'Population and dwellings']
land_area_df = revert_table_direction(land_area_df)

#merge land_area_df and diversity_scores
diversity_scores = pd.merge(land_area_df, diversity_scores, on='neighbourhood', how = 'left')

#print land_area_df
print(diversity_scores.head())
# Out:
#                   neighbourhood  Land area in square kilometres  \
# 0               Agincourt North                            7.41
# 1  Agincourt South-Malvern West                            7.83
# 2                     Alderwood                            4.95
# 3                         Annex                            2.81
# 4             Banbury-Don Mills                            9.98
#
#    total_language_population  shannon_diversity
# 0                      28845           4.799994
# 1                      23740           5.494088
# 2                      12035           4.893117
# 3                      29880           4.326750
# 4                      27480           5.816395

# %% [markdown]
# ## Calculate Overall Crime Rate for Each Neighbourhood

# %%
crime_processed_df = pd.read_csv('../static/data/processed/neighbourhood-crime-rates.csv')
crime_processed_df.head()
# Out:
#      neighbourhood crime_type  year  population  crime_count  crime_rate
# 0  Agincourt North    Assault  2014       31618           67    219.9462
# 1  Agincourt North    Assault  2015       31618           77    255.2712
# 2  Agincourt North    Assault  2016       31618           78    260.3906
# 3  Agincourt North    Assault  2017       31618           73    240.5034
# 4  Agincourt North    Assault  2018       31618           80    259.7656

# %%
# Filter for 2020 data and calculate overall crime rate
crime_2020_df = crime_processed_df[crime_processed_df['year'] == 2020]

# Group by neighbourhood to sum crime counts and get population
overall_crime_2020 = crime_2020_df.groupby('neighbourhood').agg({
    'crime_count': 'sum',
    'population': 'first'  # Take first population value as it's same for each neighborhood
}).reset_index()

# Rename the population column
overall_crime_2020 = overall_crime_2020.rename(columns={'population': 'population_2020'})

# Calculate overall crime rate per 100,000 people
overall_crime_2020['overall_crime_rate'] = (overall_crime_2020['crime_count'] / overall_crime_2020['population_2020']) * 100000

# Sort by crime rate to see distribution
print("\nTop 10 Neighborhoods by 2020 Overall Crime Rate:")
print(overall_crime_2020.sort_values('overall_crime_rate', ascending=False).head(10))

print("\nBottom 10 Neighborhoods by 2020 Overall Crime Rate:")
print(overall_crime_2020.sort_values('overall_crime_rate').head(10))

# Basic statistics of crime rates
print("\nSummary Statistics of Overall Crime Rates:")
print(overall_crime_2020['overall_crime_rate'].describe())

# Save to CSV if needed
# overall_crime_2020.to_csv('../static/data/processed/overall_crime_rate_2020.csv', index=False)
# Out:
# Top 10 Neighborhoods by 2020 Overall Crime Rate:
#                neighbourhood  crime_count  population_2020  overall_crime_rate
# 79                 Moss Park         1150            23905         4810.709057
# 62      Kensington-Chinatown          725            21196         3420.456690
# 23     Church-Yonge Corridor         1216            39279         3095.801828
# 6        Bay Street Corridor          899            32790         2741.689539
# 138  York University Heights          733            30277         2420.979621
# 124   West Humber-Clairville          892            37133         2402.175962
# 139       Yorkdale-Glen Park          397            17560         2260.820046
# 54             Humber Summit          288            13458         2139.991083
# 120               University          171             8433         2027.748132
# 13               Black Creek          450            23206         1939.153667
#
# Bottom 10 Neighborhoods by 2020 Overall Crime Rate:
#                 neighbourhood  crime_count  population_2020  \
# 112                   Steeles          104            26911
# 137            Yonge-St.Clair           66            14083
# 22     Centennial Scarborough           69            14672
# 53   Humber Heights-Westmount           58            12325
# 51             Highland Creek           68            13943
# 47                  Guildwood           54            10679
# 0             Agincourt North          168            31618
# 64             Kingsway South           58            10327
# 99         Princess-Rosethorn           70            12291
# 74                 Maple Leaf           63            10947
#
#      overall_crime_rate
# 112          386.459069
# 137          468.650146
# 22           470.283533
# 53           470.588235
# 51           487.699921
# 47           505.665324
# 0            531.342906
# 64           561.634550
# 99           569.522415
# 74           575.500137
#
# Summary Statistics of Overall Crime Rates:
# count     140.000000
# mean     1116.630522
# std       599.592739
# min       386.459069
# 25%       735.706717
# 50%       989.537395
# 75%      1285.054252
# max      4810.709057
# Name: overall_crime_rate, dtype: float64

# %%
#Merge crime rates with diversity scores
select_filter_df = pd.merge(overall_crime_2020, diversity_scores, on='neighbourhood', how = 'left')

#calculate population density
select_filter_df['population_density'] = select_filter_df['population_2020'] / select_filter_df['Land area in square kilometres']

#add a new column for householdincome in 2015
income_df = filtered_profile_df[filtered_profile_df['Topic'] == 'Income of households in 2015']
income_df = revert_table_direction(income_df)

#merge select_filter_df and income_df
select_filter_df = pd.merge(select_filter_df, income_df, on='neighbourhood', how = 'left')

print(select_filter_df.head())

#export to csv
select_filter_df.to_csv('../static/data/processed/select-filter.csv', index=False)
# Out:
#                   neighbourhood  crime_count  population_2020  \
# 0               Agincourt North          168            31618
# 1  Agincourt South-Malvern West          306            27406
# 2                     Alderwood          125            13242
# 3                         Annex          592            34680
# 4             Banbury-Don Mills          190            31186
#
#    overall_crime_rate  Land area in square kilometres  \
# 0          531.342906                            7.41
# 1         1116.543823                            7.83
# 2          943.966168                            4.95
# 3         1707.035755                            2.81
# 4          609.247739                            9.98
#
#    total_language_population  shannon_diversity  population_density  \
# 0                      28845           4.799994         4266.936572
# 1                      23740           5.494088         3500.127714
# 2                      12035           4.893117         2675.151515
# 3                      29880           4.326750        12341.637011
# 4                      27480           5.816395         3124.849699
#
#    Average after-tax income of households in 2015 ($)
# 0                                           427037.0
# 1                                           278390.0
# 2                                           168602.0
# 3                                           792507.0
# 4                                           493486.0
